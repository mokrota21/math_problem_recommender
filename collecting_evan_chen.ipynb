# %%
import requests

# %%
def save_tex(link: str, path: str):
    assert link[-4:] == '.tex'
    response = requests.get(link)
    file_path = path + '/' + link.split('/')[-1]
    if response.status_code == 200:
        pdf_file = response.content
        with open(file_path, 'wb') as f:
            f.write(pdf_file)
        return True
    else:
        return False

# %%
link_format = "https://web.evanchen.cc/exams/IMO-{year}-notes.tex"
success = True
year = 2002
path = './evan_chen'
while success:
    success = save_tex(link_format.format(year=year), path)
    year += 1

# %% [markdown]
# # Splitting

# %%
import re
from pylatexenc.latexwalker import LatexWalker, LatexEnvironmentNode

def split_latex_by_regex(latex_content, regex_pattern):
    """
    Splits LaTeX content by sections.
    
    Args:
        latex_content (str): The LaTeX document as a string.
    
    Returns:
        dict: A dictionary where each key is a section title, and value is the LaTeX content for that section.
    """
    matches = re.finditer(regex_pattern, latex_content)
    splits = {}
    start_idx = None
    current_section = None

    for match in matches:
        if current_section is not None:
            # Add the previous section
            splits[current_section] = latex_content[start_idx:match.start()].strip()
        current_section = match.group(1)
        start_idx = match.end()
    
    if current_section is not None:
        # Add the last section
        splits[current_section] = latex_content[start_idx:]
    
    return splits

def save_files(files, output_dir="unnamed problems"):
    """
    Saves each LaTeX section to a separate file.
    
    Args:
        sections (dict): Dictionary of sections and their LaTeX content.
        output_dir (str): Directory to save section files.
    """
    import os
    os.makedirs(output_dir, exist_ok=True)

    for file, content in files.items():
        pattern = r"\d+/\d"
        matches = re.findall(pattern, file)
        if matches:
            filename = matches[0].replace('/', '_P') + '.tex'
        else:
            filename = file.replace(' ', '_') + '.tex'

        filename = os.path.join(output_dir, filename)
        with open(filename, "w", encoding="utf-8") as f:
            f.write(content)
        print(f"Saved section '{file}' to {filename}")

if __name__ == "__main__":
    # Example usage
    for i in range(2002, 2025):
        filepath_header = f"./evan_chen/IMO-{i}-notes"
        filepath_tail = ".tex"
        with open(filepath_header + filepath_tail, "r", encoding="utf-8") as file:
            latex_content = file.read()

        section_pattern = r"\\section\{(.+?)\}"
        subsection_pattern = r"\\subsection\{(.+?)\}"
        enumerate_item_pattern = r"\\item %% (.+)"

        sections = split_latex_by_regex(latex_content, section_pattern)
        problem_section = sections['Problems']
        problems = split_latex_by_regex(problem_section, enumerate_item_pattern)

        solutions = split_latex_by_regex(latex_content, subsection_pattern)
        save_files(problems, filepath_header), save_files(solutions, filepath_header)
# Out:
# Saved section 'Problem 1' to ./evan_chen/IMO-2002-notes\Problem_1.tex
# Saved section 'Problem 2' to ./evan_chen/IMO-2002-notes\Problem_2.tex
# Saved section 'Problem 3' to ./evan_chen/IMO-2002-notes\Problem_3.tex
# Saved section 'Problem 4' to ./evan_chen/IMO-2002-notes\Problem_4.tex
# Saved section 'Problem 5' to ./evan_chen/IMO-2002-notes\Problem_5.tex
# Saved section 'Problem 6' to ./evan_chen/IMO-2002-notes\Problem_6.tex
# Saved section 'IMO 2002/1, proposed by Federico Ardila (COL)' to ./evan_chen/IMO-2002-notes\2002_P1.tex
# Saved section 'IMO 2002/2, proposed by Hojoo Lee (KOR)' to ./evan_chen/IMO-2002-notes\2002_P2.tex
# Saved section 'IMO 2002/3, proposed by Laurentiu Panaitopol (ROU)' to ./evan_chen/IMO-2002-notes\2002_P3.tex
# Saved section 'IMO 2002/4, proposed by Mihai Manea (ROU)' to ./evan_chen/IMO-2002-notes\2002_P4.tex
# Saved section 'IMO 2002/5, proposed by Belur Jana Venkatachala (IND)' to ./evan_chen/IMO-2002-notes\2002_P5.tex
# Saved section 'IMO 2002/6, proposed by Vyacheslav Yasinsky (UKR)' to ./evan_chen/IMO-2002-notes\2002_P6.tex
# Saved section 'Problem 1' to ./evan_chen/IMO-2003-notes\Problem_1.tex
# Saved section 'Problem 2' to ./evan_chen/IMO-2003-notes\Problem_2.tex
# Saved section 'Problem 3' to ./evan_chen/IMO-2003-notes\Problem_3.tex
# Saved section 'Problem 4' to ./evan_chen/IMO-2003-notes\Problem_4.tex
# Saved section 'Problem 5' to ./evan_chen/IMO-2003-notes\Problem_5.tex
# Saved section 'Problem 6' to ./evan_chen/IMO-2003-notes\Problem_6.tex
# Saved section 'IMO 2003/1, proposed by Carlos Gustavo Moreira (BRA)' to ./evan_chen/IMO-2003-notes\2003_P1.tex
# Saved section 'IMO 2003/2, proposed by Aleksander Ivanov (BGR)' to ./evan_chen/IMO-2003-notes\2003_P2.tex
# Saved section 'IMO 2003/3, proposed by Waldemar Pompe (POL)' to ./evan_chen/IMO-2003-notes\2003_P3.tex
# Saved section 'IMO 2003/4, proposed by Matti Lehtinen (FIN)' to ./evan_chen/IMO-2003-notes\2003_P4.tex
# Saved section 'IMO 2003/5, proposed by Finbarr Holland (IRL)' to ./evan_chen/IMO-2003-notes\2003_P5.tex
# Saved section 'IMO 2003/6, proposed by Johan Yebbou (FRA)' to ./evan_chen/IMO-2003-notes\2003_P6.tex
# Saved section 'Problem 1' to ./evan_chen/IMO-2004-notes\Problem_1.tex
# Saved section 'Problem 2' to ./evan_chen/IMO-2004-notes\Problem_2.tex
# Saved section 'Problem 3' to ./evan_chen/IMO-2004-notes\Problem_3.tex
# Saved section 'Problem 4' to ./evan_chen/IMO-2004-notes\Problem_4.tex
# Saved section 'Problem 5' to ./evan_chen/IMO-2004-notes\Problem_5.tex
# Saved section 'Problem 6' to ./evan_chen/IMO-2004-notes\Problem_6.tex
# Saved section 'IMO 2004/1, proposed by Dinu Serbanescu and Valentin Vornicu (ROU)' to ./evan_chen/IMO-2004-notes\2004_P1.tex
# Saved section 'IMO 2004/2, proposed by Hojoo Lee (KOR)' to ./evan_chen/IMO-2004-notes\2004_P2.tex
# Saved section 'IMO 2004/3, proposed by Jan Willemson (EST)' to ./evan_chen/IMO-2004-notes\2004_P3.tex
# Saved section 'IMO 2004/4, proposed by Hojoo Lee (KOR)' to ./evan_chen/IMO-2004-notes\2004_P4.tex
# Saved section 'IMO 2004/5, proposed by Waldemar Pompe (POL)' to ./evan_chen/IMO-2004-notes\2004_P5.tex
# Saved section 'IMO 2004/6, proposed by Mohsen Jamaali and Armin Morabbi (IRN)' to ./evan_chen/IMO-2004-notes\2004_P6.tex
# Saved section 'Problem 1' to ./evan_chen/IMO-2005-notes\Problem_1.tex
# Saved section 'Problem 2' to ./evan_chen/IMO-2005-notes\Problem_2.tex
# Saved section 'Problem 3' to ./evan_chen/IMO-2005-notes\Problem_3.tex
# Saved section 'Problem 4' to ./evan_chen/IMO-2005-notes\Problem_4.tex
# Saved section 'Problem 5' to ./evan_chen/IMO-2005-notes\Problem_5.tex
# Saved section 'Problem 6' to ./evan_chen/IMO-2005-notes\Problem_6.tex
# Saved section 'IMO 2005/1, proposed by Bogdan Enescu (ROU)' to ./evan_chen/IMO-2005-notes\2005_P1.tex
# Saved section 'IMO 2005/2, proposed by Nicholas de Bruijn (NLD)' to ./evan_chen/IMO-2005-notes\2005_P2.tex
# Saved section 'IMO 2005/3, proposed by Hojoo Lee (KOR)' to ./evan_chen/IMO-2005-notes\2005_P3.tex
# Saved section 'IMO 2005/4, proposed by Mariusz Skalba (POL)' to ./evan_chen/IMO-2005-notes\2005_P4.tex
# Saved section 'IMO 2005/5, proposed by Waldemar Pompe (POL)' to ./evan_chen/IMO-2005-notes\2005_P5.tex
# Saved section 'IMO 2005/6, proposed by Radu Gologan, Dan Schwartz (ROU)' to ./evan_chen/IMO-2005-notes\2005_P6.tex
# Saved section 'Problem 1' to ./evan_chen/IMO-2006-notes\Problem_1.tex
# Saved section 'Problem 2' to ./evan_chen/IMO-2006-notes\Problem_2.tex
# Saved section 'Problem 3' to ./evan_chen/IMO-2006-notes\Problem_3.tex
# Saved section 'Problem 4' to ./evan_chen/IMO-2006-notes\Problem_4.tex
# Saved section 'Problem 5' to ./evan_chen/IMO-2006-notes\Problem_5.tex
# Saved section 'Problem 6' to ./evan_chen/IMO-2006-notes\Problem_6.tex
# Saved section 'IMO 2006/1, proposed by Hojoo Lee (KOR)' to ./evan_chen/IMO-2006-notes\2006_P1.tex
# Saved section 'IMO 2006/2, proposed by Dušan Djukić (SRB)' to ./evan_chen/IMO-2006-notes\2006_P2.tex
# Saved section 'IMO 2006/3, proposed by Finbarr Holland (IRL)' to ./evan_chen/IMO-2006-notes\2006_P3.tex
# Saved section 'IMO 2006/4, proposed by Zuming Feng (USA)' to ./evan_chen/IMO-2006-notes\2006_P4.tex
# Saved section 'IMO 2006/5, proposed by Dan Schwarz (ROU)' to ./evan_chen/IMO-2006-notes\2006_P5.tex
# Saved section 'IMO 2006/6, proposed by Dušan Djukić (SRB)' to ./evan_chen/IMO-2006-notes\2006_P6.tex
# Saved section 'Problem 1' to ./evan_chen/IMO-2007-notes\Problem_1.tex
# Saved section 'Problem 2' to ./evan_chen/IMO-2007-notes\Problem_2.tex
# Saved section 'Problem 3' to ./evan_chen/IMO-2007-notes\Problem_3.tex
# Saved section 'Problem 4' to ./evan_chen/IMO-2007-notes\Problem_4.tex
# Saved section 'Problem 5' to ./evan_chen/IMO-2007-notes\Problem_5.tex
# Saved section 'Problem 6' to ./evan_chen/IMO-2007-notes\Problem_6.tex
# Saved section 'IMO 2007/1, proposed by Michael Albert (NZL)' to ./evan_chen/IMO-2007-notes\2007_P1.tex
# Saved section 'IMO 2007/2, proposed by Charles Leytem (LUX)' to ./evan_chen/IMO-2007-notes\2007_P2.tex
# Saved section 'IMO 2007/3, proposed by Vasily Astakhov (RUS)' to ./evan_chen/IMO-2007-notes\2007_P3.tex
# Saved section 'IMO 2007/4, proposed by Marek Pechal (CZE)' to ./evan_chen/IMO-2007-notes\2007_P4.tex
# Saved section 'IMO 2007/5, proposed by Kevin Buzzard, Edward Crane (UNK)' to ./evan_chen/IMO-2007-notes\2007_P5.tex
# Saved section 'IMO 2007/6, proposed by Gerhard Woeginger (NLD)' to ./evan_chen/IMO-2007-notes\2007_P6.tex
# Saved section 'Problem 1' to ./evan_chen/IMO-2008-notes\Problem_1.tex
# Saved section 'Problem 2' to ./evan_chen/IMO-2008-notes\Problem_2.tex
# Saved section 'Problem 3' to ./evan_chen/IMO-2008-notes\Problem_3.tex
# Saved section 'Problem 4' to ./evan_chen/IMO-2008-notes\Problem_4.tex
# Saved section 'Problem 5' to ./evan_chen/IMO-2008-notes\Problem_5.tex
# Saved section 'Problem 6' to ./evan_chen/IMO-2008-notes\Problem_6.tex
# Saved section 'IMO 2008/1, proposed by Andrey Gavrilyuk (RUS)' to ./evan_chen/IMO-2008-notes\2008_P1.tex
# Saved section 'IMO 2008/2, proposed by Walther Janous (AUT)' to ./evan_chen/IMO-2008-notes\2008_P2.tex
# Saved section 'IMO 2008/3, proposed by Kęstutis Česnavičius (LTU)' to ./evan_chen/IMO-2008-notes\2008_P3.tex
# Saved section 'IMO 2008/4, proposed by Hojoo Lee (KOR)' to ./evan_chen/IMO-2008-notes\2008_P4.tex
# Saved section 'IMO 2008/5, proposed by Bruno Le Floch and Ilia Smilga (FRA)' to ./evan_chen/IMO-2008-notes\2008_P5.tex
# Saved section 'IMO 2008/6, proposed by Vladimir Shmarov (RUS)' to ./evan_chen/IMO-2008-notes\2008_P6.tex
# Saved section 'Problem 1' to ./evan_chen/IMO-2009-notes\Problem_1.tex
# Saved section 'Problem 2' to ./evan_chen/IMO-2009-notes\Problem_2.tex
# Saved section 'Problem 3' to ./evan_chen/IMO-2009-notes\Problem_3.tex
# Saved section 'Problem 4' to ./evan_chen/IMO-2009-notes\Problem_4.tex
# Saved section 'Problem 5' to ./evan_chen/IMO-2009-notes\Problem_5.tex
# Saved section 'Problem 6' to ./evan_chen/IMO-2009-notes\Problem_6.tex
# Saved section 'IMO 2009/1, proposed by Ross Atkins (AUS)' to ./evan_chen/IMO-2009-notes\2009_P1.tex
# Saved section 'IMO 2009/2, proposed by Sergei Berlov (RUS)' to ./evan_chen/IMO-2009-notes\2009_P2.tex
# Saved section 'IMO 2009/3, proposed by Gabriel Carroll (USA)' to ./evan_chen/IMO-2009-notes\2009_P3.tex
# Saved section 'IMO 2009/4, proposed by Hojoo Lee, Peter Vandendriessche, Jan Vonk (BEL)' to ./evan_chen/IMO-2009-notes\2009_P4.tex
# Saved section 'IMO 2009/5, proposed by Bruno Le Floch (FRA)' to ./evan_chen/IMO-2009-notes\2009_P5.tex
# Saved section 'IMO 2009/6, proposed by Dmitry Khramtsov (RUS)' to ./evan_chen/IMO-2009-notes\2009_P6.tex
# Saved section 'Problem 1' to ./evan_chen/IMO-2010-notes\Problem_1.tex
# Saved section 'Problem 2' to ./evan_chen/IMO-2010-notes\Problem_2.tex
# Saved section 'Problem 3' to ./evan_chen/IMO-2010-notes\Problem_3.tex
# Saved section 'Problem 4' to ./evan_chen/IMO-2010-notes\Problem_4.tex
# Saved section 'Problem 5' to ./evan_chen/IMO-2010-notes\Problem_5.tex
# Saved section 'Problem 6' to ./evan_chen/IMO-2010-notes\Problem_6.tex
# Saved section 'IMO 2010/1, proposed by Pierre Bornsztein (FRA)' to ./evan_chen/IMO-2010-notes\2010_P1.tex
# Saved section 'IMO 2010/2, proposed by Tai Wai Ming and Wang Chongli (HKG)' to ./evan_chen/IMO-2010-notes\2010_P2.tex
# Saved section 'IMO 2010/3, proposed by Gabriel Carroll (USA)' to ./evan_chen/IMO-2010-notes\2010_P3.tex
# Saved section 'IMO 2010/4, proposed by Marcin Kuczma (POL)' to ./evan_chen/IMO-2010-notes\2010_P4.tex
# Saved section 'IMO 2010/5, proposed by Netherlands' to ./evan_chen/IMO-2010-notes\2010_P5.tex
# Saved section 'IMO 2010/6, proposed by Morteza Saghafiyan (IRN)' to ./evan_chen/IMO-2010-notes\2010_P6.tex
# Saved section 'Problem 1' to ./evan_chen/IMO-2011-notes\Problem_1.tex
# Saved section 'Problem 2' to ./evan_chen/IMO-2011-notes\Problem_2.tex
# Saved section 'Problem 3' to ./evan_chen/IMO-2011-notes\Problem_3.tex
# Saved section 'Problem 4' to ./evan_chen/IMO-2011-notes\Problem_4.tex
# Saved section 'Problem 5' to ./evan_chen/IMO-2011-notes\Problem_5.tex
# Saved section 'Problem 6' to ./evan_chen/IMO-2011-notes\Problem_6.tex
# Saved section 'IMO 2011/1, proposed by Fernando Campos (MEX)' to ./evan_chen/IMO-2011-notes\2011_P1.tex
# Saved section 'IMO 2011/2, proposed by Geoff Smith (UNK)' to ./evan_chen/IMO-2011-notes\2011_P2.tex
# Saved section 'IMO 2011/3, proposed by Igor Voronovich, BLR' to ./evan_chen/IMO-2011-notes\2011_P3.tex
# Saved section 'IMO 2011/4, proposed by Morteza Saghafian (IRN)' to ./evan_chen/IMO-2011-notes\2011_P4.tex
# Saved section 'IMO 2011/5, proposed by Mahyar Sefidgaran (IRN)' to ./evan_chen/IMO-2011-notes\2011_P5.tex
# Saved section 'IMO 2011/6, proposed by Japan' to ./evan_chen/IMO-2011-notes\2011_P6.tex
# Saved section 'Problem 1' to ./evan_chen/IMO-2012-notes\Problem_1.tex
# Saved section 'Problem 2' to ./evan_chen/IMO-2012-notes\Problem_2.tex
# Saved section 'Problem 3' to ./evan_chen/IMO-2012-notes\Problem_3.tex
# Saved section 'Problem 4' to ./evan_chen/IMO-2012-notes\Problem_4.tex
# Saved section 'Problem 5' to ./evan_chen/IMO-2012-notes\Problem_5.tex
# Saved section 'Problem 6' to ./evan_chen/IMO-2012-notes\Problem_6.tex
# Saved section 'IMO 2012/1, proposed by Evangelos Psychas (HEL)' to ./evan_chen/IMO-2012-notes\2012_P1.tex
# Saved section 'IMO 2012/2, proposed by Angelo di Pasquale (AUS)' to ./evan_chen/IMO-2012-notes\2012_P2.tex
# Saved section 'IMO 2012/3, proposed by David Arthur (CAN)' to ./evan_chen/IMO-2012-notes\2012_P3.tex
# Saved section 'IMO 2012/4, proposed by Liam Baker (SAF)' to ./evan_chen/IMO-2012-notes\2012_P4.tex
# Saved section 'IMO 2012/5, proposed by Josef Tkadlec (CZE)' to ./evan_chen/IMO-2012-notes\2012_P5.tex
# Saved section 'IMO 2012/6, proposed by Dusan Djukic (SRB)' to ./evan_chen/IMO-2012-notes\2012_P6.tex
# Saved section 'Problem 1' to ./evan_chen/IMO-2013-notes\Problem_1.tex
# Saved section 'Problem 2' to ./evan_chen/IMO-2013-notes\Problem_2.tex
# Saved section 'Problem 3' to ./evan_chen/IMO-2013-notes\Problem_3.tex
# Saved section 'Problem 4' to ./evan_chen/IMO-2013-notes\Problem_4.tex
# Saved section 'Problem 5' to ./evan_chen/IMO-2013-notes\Problem_5.tex
# Saved section 'Problem 6' to ./evan_chen/IMO-2013-notes\Problem_6.tex
# Saved section 'IMO 2013/1, proposed by Japan' to ./evan_chen/IMO-2013-notes\2013_P1.tex
# Saved section 'IMO 2013/2, proposed by Ivan Guo (AUS)' to ./evan_chen/IMO-2013-notes\2013_P2.tex
# Saved section 'IMO 2013/3, proposed by Alexander A. Polyansky (RUS)' to ./evan_chen/IMO-2013-notes\2013_P3.tex
# Saved section 'IMO 2013/4, proposed by Warut Suksompong, Potcharapol Suteparuk (THA)' to ./evan_chen/IMO-2013-notes\2013_P4.tex
# Saved section 'IMO 2013/5, proposed by Nikolai Nikolov (BGR)' to ./evan_chen/IMO-2013-notes\2013_P5.tex
# Saved section 'IMO 2013/6, proposed by Alexander S. Golovanov and Mikhail A. Ivanov (RUS)' to ./evan_chen/IMO-2013-notes\2013_P6.tex
# Saved section 'Problem 1' to ./evan_chen/IMO-2014-notes\Problem_1.tex
# Saved section 'Problem 2' to ./evan_chen/IMO-2014-notes\Problem_2.tex
# Saved section 'Problem 3' to ./evan_chen/IMO-2014-notes\Problem_3.tex
# Saved section 'Problem 4' to ./evan_chen/IMO-2014-notes\Problem_4.tex
# Saved section 'Problem 5' to ./evan_chen/IMO-2014-notes\Problem_5.tex
# Saved section 'Problem 6' to ./evan_chen/IMO-2014-notes\Problem_6.tex
# Saved section 'IMO 2014/1, proposed by Gerhard Woeginger (AUT)' to ./evan_chen/IMO-2014-notes\2014_P1.tex
# Saved section 'IMO 2014/2, proposed by Tonči Kokan (HRV)' to ./evan_chen/IMO-2014-notes\2014_P2.tex
# Saved section 'IMO 2014/3, proposed by ALi Zamani (IRN)' to ./evan_chen/IMO-2014-notes\2014_P3.tex
# Saved section 'IMO 2014/4, proposed by Giorgi Arabidze (GEO)' to ./evan_chen/IMO-2014-notes\2014_P4.tex
# Saved section 'IMO 2014/5, proposed by Gerhard Woeginger (LUX)' to ./evan_chen/IMO-2014-notes\2014_P5.tex
# Saved section 'IMO 2014/6, proposed by Gerhard Woeginger (AUT)' to ./evan_chen/IMO-2014-notes\2014_P6.tex
# Saved section 'Problem 1' to ./evan_chen/IMO-2015-notes\Problem_1.tex
# Saved section 'Problem 2' to ./evan_chen/IMO-2015-notes\Problem_2.tex
# Saved section 'Problem 3' to ./evan_chen/IMO-2015-notes\Problem_3.tex
# Saved section 'Problem 4' to ./evan_chen/IMO-2015-notes\Problem_4.tex
# Saved section 'Problem 5' to ./evan_chen/IMO-2015-notes\Problem_5.tex
# Saved section 'Problem 6' to ./evan_chen/IMO-2015-notes\Problem_6.tex
# Saved section 'IMO 2015/1, proposed by Merlijn Staps (NLD)' to ./evan_chen/IMO-2015-notes\2015_P1.tex
# Saved section 'IMO 2015/2, proposed by Dušan Djukić (SRB)' to ./evan_chen/IMO-2015-notes\2015_P2.tex
# Saved section 'IMO 2015/3, proposed by Danylo Khilko and Mykhailo Plotnikov (UKR)' to ./evan_chen/IMO-2015-notes\2015_P3.tex
# Saved section 'IMO 2015/4, proposed by Silouanos Brazitikos and Evangelos Psychas (HEL)' to ./evan_chen/IMO-2015-notes\2015_P4.tex
# Saved section 'IMO 2015/5, proposed by Dorlir Ahmeti (ALB)' to ./evan_chen/IMO-2015-notes\2015_P5.tex
# Saved section 'IMO 2015/6, proposed by Ross Atkins and Ivan Guo (AUS)' to ./evan_chen/IMO-2015-notes\2015_P6.tex
# Saved section 'Problem 1' to ./evan_chen/IMO-2016-notes\Problem_1.tex
# Saved section 'Problem 2' to ./evan_chen/IMO-2016-notes\Problem_2.tex
# Saved section 'Problem 3' to ./evan_chen/IMO-2016-notes\Problem_3.tex
# Saved section 'Problem 4' to ./evan_chen/IMO-2016-notes\Problem_4.tex
# Saved section 'Problem 5' to ./evan_chen/IMO-2016-notes\Problem_5.tex
# Saved section 'Problem 6' to ./evan_chen/IMO-2016-notes\Problem_6.tex
# Saved section 'IMO 2016/1, proposed by Art Waeterschoot (BEL)' to ./evan_chen/IMO-2016-notes\2016_P1.tex
# Saved section 'IMO 2016/2, proposed by Trevor Tau (AUS)' to ./evan_chen/IMO-2016-notes\2016_P2.tex
# Saved section 'IMO 2016/3, proposed by Aleksandr Gaifullin (RUS)' to ./evan_chen/IMO-2016-notes\2016_P3.tex
# Saved section 'IMO 2016/4, proposed by Gerhard Woeginger (LUX)' to ./evan_chen/IMO-2016-notes\2016_P4.tex
# Saved section 'IMO 2016/5, proposed by Russia' to ./evan_chen/IMO-2016-notes\2016_P5.tex
# Saved section 'IMO 2016/6, proposed by Josef Tkadlec (CZE)' to ./evan_chen/IMO-2016-notes\2016_P6.tex
# Saved section 'Problem 1' to ./evan_chen/IMO-2017-notes\Problem_1.tex
# Saved section 'Problem 2' to ./evan_chen/IMO-2017-notes\Problem_2.tex
# Saved section 'Problem 3' to ./evan_chen/IMO-2017-notes\Problem_3.tex
# Saved section 'Problem 4' to ./evan_chen/IMO-2017-notes\Problem_4.tex
# Saved section 'Problem 5' to ./evan_chen/IMO-2017-notes\Problem_5.tex
# Saved section 'Problem 6' to ./evan_chen/IMO-2017-notes\Problem_6.tex
# Saved section 'IMO 2017/1, proposed by Stephan Wagner (SAF)' to ./evan_chen/IMO-2017-notes\2017_P1.tex
# Saved section 'IMO 2017/2, proposed by Dorlir Ahmeti (ALB)' to ./evan_chen/IMO-2017-notes\2017_P2.tex
# Saved section 'IMO 2017/3, proposed by Gerhard Woeginger (AUT)' to ./evan_chen/IMO-2017-notes\2017_P3.tex
# Saved section 'IMO 2017/4, proposed by Charles Leytem (LUX)' to ./evan_chen/IMO-2017-notes\2017_P4.tex
# Saved section 'IMO 2017/5, proposed by Grigory Chelnokov (RUS)' to ./evan_chen/IMO-2017-notes\2017_P5.tex
# Saved section 'IMO 2017/6, proposed by John Berman (USA)' to ./evan_chen/IMO-2017-notes\2017_P6.tex
# Saved section 'Problem 1' to ./evan_chen/IMO-2018-notes\Problem_1.tex
# Saved section 'Problem 2' to ./evan_chen/IMO-2018-notes\Problem_2.tex
# Saved section 'Problem 3' to ./evan_chen/IMO-2018-notes\Problem_3.tex
# Saved section 'Problem 4' to ./evan_chen/IMO-2018-notes\Problem_4.tex
# Saved section 'Problem 5' to ./evan_chen/IMO-2018-notes\Problem_5.tex
# Saved section 'Problem 6' to ./evan_chen/IMO-2018-notes\Problem_6.tex
# Saved section 'IMO 2018/1, proposed by Silouanos Brazitikos, Vangelis Psyxas, Michael Sarantis (HEL)' to ./evan_chen/IMO-2018-notes\2018_P1.tex
# Saved section 'IMO 2018/2, proposed by Patrik Bak (SVK)' to ./evan_chen/IMO-2018-notes\2018_P2.tex
# Saved section 'IMO 2018/3, proposed by Morteza Saghafian (IRN)' to ./evan_chen/IMO-2018-notes\2018_P3.tex
# Saved section 'IMO 2018/4, proposed by Gurgen Asatryan (ARM)' to ./evan_chen/IMO-2018-notes\2018_P4.tex
# Saved section 'IMO 2018/5, proposed by Bayarmagnai Gombodorj (MNG)' to ./evan_chen/IMO-2018-notes\2018_P5.tex
# Saved section 'IMO 2018/6, proposed by Tomasz Ciesla (POL)' to ./evan_chen/IMO-2018-notes\2018_P6.tex
# Saved section 'Problem 1' to ./evan_chen/IMO-2019-notes\Problem_1.tex
# Saved section 'Problem 2' to ./evan_chen/IMO-2019-notes\Problem_2.tex
# Saved section 'Problem 3' to ./evan_chen/IMO-2019-notes\Problem_3.tex
# Saved section 'Problem 4' to ./evan_chen/IMO-2019-notes\Problem_4.tex
# Saved section 'Problem 5' to ./evan_chen/IMO-2019-notes\Problem_5.tex
# Saved section 'Problem 6' to ./evan_chen/IMO-2019-notes\Problem_6.tex
# Saved section 'IMO 2019/1, proposed by Liam Baker (SAF)' to ./evan_chen/IMO-2019-notes\2019_P1.tex
# Saved section 'IMO 2019/2, proposed by Anton Trygub (UKR)' to ./evan_chen/IMO-2019-notes\2019_P2.tex
# Saved section 'IMO 2019/3, proposed by Adrian Beker (HRV)' to ./evan_chen/IMO-2019-notes\2019_P3.tex
# Saved section 'IMO 2019/4, proposed by Gabriel Chicas Reyes (SLV)' to ./evan_chen/IMO-2019-notes\2019_P4.tex
# Saved section 'IMO 2019/5, proposed by David Altizio (USA)' to ./evan_chen/IMO-2019-notes\2019_P5.tex
# Saved section 'IMO 2019/6, proposed by Anant Mudgal (IND)' to ./evan_chen/IMO-2019-notes\2019_P6.tex
# Saved section 'Problem 1' to ./evan_chen/IMO-2020-notes\Problem_1.tex
# Saved section 'Problem 2' to ./evan_chen/IMO-2020-notes\Problem_2.tex
# Saved section 'Problem 3' to ./evan_chen/IMO-2020-notes\Problem_3.tex
# Saved section 'Problem 4' to ./evan_chen/IMO-2020-notes\Problem_4.tex
# Saved section 'Problem 5' to ./evan_chen/IMO-2020-notes\Problem_5.tex
# Saved section 'Problem 6' to ./evan_chen/IMO-2020-notes\Problem_6.tex
# Saved section 'IMO 2020/1, proposed by Dominik Burek (POL)' to ./evan_chen/IMO-2020-notes\2020_P1.tex
# Saved section 'IMO 2020/2, proposed by Belarus' to ./evan_chen/IMO-2020-notes\2020_P2.tex
# Saved section 'IMO 2020/3, proposed by Milan Haiman (HUN), Carl Schildkraut (USA)' to ./evan_chen/IMO-2020-notes\2020_P3.tex
# Saved section 'IMO 2020/4, proposed by Tejaswi Navilarekallu (IND)' to ./evan_chen/IMO-2020-notes\2020_P4.tex
# Saved section 'IMO 2020/5, proposed by Oleg Ko\v{s' to ./evan_chen/IMO-2020-notes\2020_P5.tex
# Saved section 'IMO 2020/6, proposed by Ting-Feng Lin, Hung-Hsun Hans Yu (TWN)' to ./evan_chen/IMO-2020-notes\2020_P6.tex
# Saved section 'Problem 1' to ./evan_chen/IMO-2021-notes\Problem_1.tex
# Saved section 'Problem 2' to ./evan_chen/IMO-2021-notes\Problem_2.tex
# Saved section 'Problem 3' to ./evan_chen/IMO-2021-notes\Problem_3.tex
# Saved section 'Problem 4' to ./evan_chen/IMO-2021-notes\Problem_4.tex
# Saved section 'Problem 5' to ./evan_chen/IMO-2021-notes\Problem_5.tex
# Saved section 'Problem 6' to ./evan_chen/IMO-2021-notes\Problem_6.tex
# Saved section 'IMO 2021/1, proposed by Australia' to ./evan_chen/IMO-2021-notes\2021_P1.tex
# Saved section 'IMO 2021/2, proposed by Calvin Deng' to ./evan_chen/IMO-2021-notes\2021_P2.tex
# Saved section 'IMO 2021/3, proposed by Mykhalio Shtandenko (UKR)' to ./evan_chen/IMO-2021-notes\2021_P3.tex
# Saved section 'IMO 2021/4, proposed by Dominik Burek (POL) and Tomasz Ciesla (POL)' to ./evan_chen/IMO-2021-notes\2021_P4.tex
# Saved section 'IMO 2021/5, proposed by Spain' to ./evan_chen/IMO-2021-notes\2021_P5.tex
# Saved section 'IMO 2021/6, proposed by Austria' to ./evan_chen/IMO-2021-notes\2021_P6.tex
# Saved section 'Problem 1' to ./evan_chen/IMO-2022-notes\Problem_1.tex
# Saved section 'Problem 2' to ./evan_chen/IMO-2022-notes\Problem_2.tex
# Saved section 'Problem 3' to ./evan_chen/IMO-2022-notes\Problem_3.tex
# Saved section 'Problem 4' to ./evan_chen/IMO-2022-notes\Problem_4.tex
# Saved section 'Problem 5' to ./evan_chen/IMO-2022-notes\Problem_5.tex
# Saved section 'Problem 6' to ./evan_chen/IMO-2022-notes\Problem_6.tex
# Saved section 'IMO 2022/1, proposed by Baptiste Serraille (FRA)' to ./evan_chen/IMO-2022-notes\2022_P1.tex
# Saved section 'IMO 2022/2, proposed by Merlijn Staps (NLD)' to ./evan_chen/IMO-2022-notes\2022_P2.tex
# Saved section 'IMO 2022/3, proposed by Ankan Bhattacharya (USA)' to ./evan_chen/IMO-2022-notes\2022_P3.tex
# Saved section 'IMO 2022/4, proposed by Patrik Bak (SVK)' to ./evan_chen/IMO-2022-notes\2022_P4.tex
# Saved section 'IMO 2022/5, proposed by Tijs Buggenhout (BEL)' to ./evan_chen/IMO-2022-notes\2022_P5.tex
# Saved section 'IMO 2022/6, proposed by Nikola Petrovi\'{c' to ./evan_chen/IMO-2022-notes\2022_P6.tex
# Saved section 'Problem 1' to ./evan_chen/IMO-2023-notes\Problem_1.tex
# Saved section 'Problem 2' to ./evan_chen/IMO-2023-notes\Problem_2.tex
# Saved section 'Problem 3' to ./evan_chen/IMO-2023-notes\Problem_3.tex
# Saved section 'Problem 4' to ./evan_chen/IMO-2023-notes\Problem_4.tex
# Saved section 'Problem 5' to ./evan_chen/IMO-2023-notes\Problem_5.tex
# Saved section 'Problem 6' to ./evan_chen/IMO-2023-notes\Problem_6.tex
# Saved section 'IMO 2023/1, proposed by Santiago Rodriguez (COL)' to ./evan_chen/IMO-2023-notes\2023_P1.tex
# Saved section 'IMO 2023/2, proposed by Tiago Mourão and Nuno Arala (POR)' to ./evan_chen/IMO-2023-notes\2023_P2.tex
# Saved section 'IMO 2023/3, proposed by Ivan Chan (MAS)' to ./evan_chen/IMO-2023-notes\2023_P3.tex
# Saved section 'IMO 2023/4, proposed by Merlijn Staps (NLD)' to ./evan_chen/IMO-2023-notes\2023_P4.tex
# Saved section 'IMO 2023/5, proposed by Merlijn Staps and Daniël Kroes (NLD)' to ./evan_chen/IMO-2023-notes\2023_P5.tex
# Saved section 'IMO 2023/6, proposed by Ankan Bhattacharya, Luke Robitaille (USA)' to ./evan_chen/IMO-2023-notes\2023_P6.tex
# Saved section 'Problem 1' to ./evan_chen/IMO-2024-notes\Problem_1.tex
# Saved section 'Problem 2' to ./evan_chen/IMO-2024-notes\Problem_2.tex
# Saved section 'Problem 3' to ./evan_chen/IMO-2024-notes\Problem_3.tex
# Saved section 'Problem 4' to ./evan_chen/IMO-2024-notes\Problem_4.tex
# Saved section 'Problem 5' to ./evan_chen/IMO-2024-notes\Problem_5.tex
# Saved section 'Problem 6' to ./evan_chen/IMO-2024-notes\Problem_6.tex
# Saved section 'IMO 2024/1, proposed by Santiago Rodriguez (COL)' to ./evan_chen/IMO-2024-notes\2024_P1.tex
# Saved section 'IMO 2024/2, proposed by Valentino Iverson (IDN)' to ./evan_chen/IMO-2024-notes\2024_P2.tex
# Saved section 'IMO 2024/3, proposed by William Steinberg (AUS)' to ./evan_chen/IMO-2024-notes\2024_P3.tex
# Saved section 'IMO 2024/4, proposed by Dominik Burek (POL)' to ./evan_chen/IMO-2024-notes\2024_P4.tex
# Saved section 'IMO 2024/5, proposed by Chu Cheuk Hei (HKG)' to ./evan_chen/IMO-2024-notes\2024_P5.tex
# Saved section 'IMO 2024/6, proposed by Japan' to ./evan_chen/IMO-2024-notes\2024_P6.tex
