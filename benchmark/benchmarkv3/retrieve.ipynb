# %%
import pandas as pd
qa_df = pd.read_csv("q&a.csv")

# %%
row = qa_df.iloc[0].to_dict()
row
# Out:
# {'Anchor': 431,
#  'Golden': 439,
#  'Silver': 475,
#  'Wrong': 592,
#  'Query': 'Find problems that use '}

# %%
df = pd.read_csv("df.csv")
texts = {}
for k in row:
    if k == "Query":
        continue

    texts[k] = df[df['id'] == row[k]].iloc[0].to_dict()

# %%
from pprint import pprint
pprint(texts)
# Out:
# {'Anchor': {'Problem': 'Problem. Find all odd positive integers n greater than '
#                        '1 such that for any relatively prime divisors a and '
#                        '$b$ of $n$ , the number $a+b-1$ is also a divisor of '
#                        '$n$ .  \n'
#                        '\n'
#                        '(2001 Russian Mathematical Olympiad)  \n'
#                        '\n',
#             'Problem Book No': '1.1.11.',
#             'Problem&Solution': 'Problem. Find all odd positive integers n '
#                                 'greater than 1 such that for any relatively '
#                                 'prime divisors a and $b$ of $n$ , the number '
#                                 '$a+b-1$ is also a divisor of $n$ .  \n'
#                                 '\n'
#                                 '(2001 Russian Mathematical Olympiad)  \n'
#                                 '\n'
# ...
